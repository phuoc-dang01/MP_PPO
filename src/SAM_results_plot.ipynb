# %%
import pandas as pd

# %%
with open("./ppo/log_test.txt", "rb") as f:
    _d = f.read()

# %%
df = pd.read_csv("./ppo/log_test.txt", delimiter='\t', header=None)

# %%
df
# Out:
#          0         1         2         3         4         5         6
# 0        0  0.038298  0.115000  0.451995  0.457447  0.779947  0.851064
# 1      300  3.215957  3.317606  3.584441  3.569149  3.799840  3.832979
# 2      600  3.419149  3.451915  3.644548  3.661702  3.799840  3.832979
# 3      900  2.912766  2.964149  3.243883  3.189362  3.621649  3.695745
# 4     1200  3.691489  3.693723  3.834441  3.823404  4.008723  4.048936
# ..     ...       ...       ...       ...       ...       ...       ...
# 119  35700  3.681915  3.708723  3.894415  3.881915  4.076436  4.079787
# 120  36000  3.758511  3.781223  3.971144  4.008511  4.079787  4.079787
# 121  36300  3.715957  3.753564  3.968484  4.008511  4.093617  4.101064
# 122  36600  3.715957  3.753564  3.949601  3.962234  4.068723  4.070213
# 123  36900  3.680851  3.681223  3.876330  3.909574  4.044043  4.079787
#
# [124 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# Set the dimensions of the plot
plt.figure(figsize=(8, 4))  # Width=8 inches, Height=4 inches

# Create a line plot
plt.plot(df[0], df[3])

# Adding title and labels
plt.title('Average reward over time')
plt.xlabel('Epoch')
plt.ylabel('Avg Reward')

# Show the plot
plt.savefig("reward_over_time.png", dpi=600)
plt.show()
